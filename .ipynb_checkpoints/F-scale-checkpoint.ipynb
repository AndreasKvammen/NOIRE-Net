# %% [markdown]
# # F-scale: This Notebook develops and evaluates the NOIRE-Net F-region scaling networks

# %% [markdown]
# ## 1 - Develop NOIRE-Net

# %% [markdown]
# ### 1.1 - Import libaries

# %%
import os
import random
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Dropout
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from sklearn.metrics import mean_squared_error
from math import sqrt
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from sklearn.metrics import cohen_kappa_score, precision_score, recall_score, f1_score, accuracy_score

# %% [markdown]
# ### 1.2 - Define function to get F-region scaling parameters from .par file (item1 = foF, item2 = hF)

# %%
# The function get_regression_label_from_par reads a .par file and returns 
# the F-region maximum O-mode frequency and the F-region height.
# Both the foF and hF must be values (can not be 'nan'). 

def get_regression_label_from_par(par_file_path):
    try:
        # Open the file at the specified path
        with open(par_file_path, 'r') as file:
            content = file.readline().strip()  # Read the first line and remove leading/trailing whitespace
            items = content.split()  # Split the line into individual items

            # Check if both the first and third items are not 'nan' (not a number)
            # If they are both valid numbers, convert them to floats and return them as a tuple
            if items[0].lower() != 'nan' and items[2].lower() != 'nan':
                return float(items[0]), float(items[2])
            else:
                # If either item is 'nan', return None
                return None
    except Exception as e:
        # Print an error message if an exception occurs while processing the file
        print(f"Error reading {par_file_path}: {e}")
        # Return None if there is an error
        return None

# %% [markdown]
# ### 1.3 - Define function to load ionograms and preprocess the data

# %%
# The load_data function loads and preprocesses image data from a specified directory,
# converting images to grayscale and resizing them, while also extracting corresponding
# scaling parameters from associated .par files for a regression task.

def load_data(data_dir, target_size=(310, 310)):
    images = []  # List to store preprocessed images
    labels = []  # List to store corresponding regression labels

    # Construct paths to the directories containing ionograms and parameters
    ionograms_dir = os.path.join(data_dir, 'ionograms')
    parameters_dir = os.path.join(data_dir, 'parameters')

    # Iterate over the files in the ionograms directory
    for filename in os.listdir(ionograms_dir):
        if filename.endswith('.png'):  # Check if the file is a PNG image
            # Construct full paths to the image file and its corresponding .par file
            img_path = os.path.join(ionograms_dir, filename)
            par_path = os.path.join(parameters_dir, filename.replace('.png', '.par'))

            # Load the image, convert it to grayscale, resize it, and normalize pixel values
            image = load_img(img_path, color_mode='grayscale', target_size=target_size)
            image = img_to_array(image) / 255.0  # Normalize image pixels to be between 0 and 1

            # Get the regression labels from the .par file
            regression_label = get_regression_label_from_par(par_path)
            
            # Proceed only if valid regression labels are found
            if regression_label is not None:
                images.append(image)
                labels.append(regression_label)

    # Convert the lists of images and labels to numpy arrays and return them
    return np.array(images), np.array(labels)

# %% [markdown]
# ### 1.4 - Load the ionograms and labels from the data folder

# %%
# Specify the directory where the data is stored
data_dir = 'train-val'  # 'train_test_val' should be replaced with the actual path to your data directory

# Call the load_data function to load and preprocess the data
# X wildsdsdl contain the preprocessed images, and y will contain the corresponding labels
X, y = load_data(data_dir)

# %% [markdown]
# ### 1.5 - Define a function to create the NOIRE-Net architecture

# %%
# This code defines and complies NOIRE-Net a convolutional neural network (CNN) model using Keras, 
# with multiple convolutional layers, batch normalization, max pooling, and dense layers, 
# designed for binary classification tasks.

def NOIREnet():
    model = Sequential([
    # First convolutional layer with 32 filters and a kernel size of 3x3
    # 'padding=same' ensures the output size is the same as the input size
    # 'input_shape' is set for the first layer to indicate the shape of the input data
    Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(310, 310, 1)),
    
    # Batch normalization to normalize the activations from the previous layer
    BatchNormalization(),

    # Second convolutional layer with 32 filters and a kernel size of 3x3
    Conv2D(32, (3, 3), activation='relu'),

    # Another batch normalization
    BatchNormalization(),

    # First max pooling layer to reduce spatial dimensions
    MaxPooling2D((2, 2)),

    # Repeating the pattern of two convolutional layers followed by batch normalization
    # and a max pooling layer, gradually increasing the number of filters
    Conv2D(32, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(32, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),

    Conv2D(64, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),

    Conv2D(64, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),

    Conv2D(128, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),

    Conv2D(128, (3, 3), padding='same', activation='relu'),
    BatchNormalization(),
    Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),

    # Flatten the output from the convolutional layers to feed into dense layers
    Flatten(),

    # Dense (fully connected) layer with 256 neurons and relu activation
    Dense(256, activation='relu'),

    # Dropout layer to reduce overfitting
    Dropout(0.5),

    # Another dense layer with 128 neurons
    Dense(128, activation='relu'),

    # Output layer with a single neuron and sigmoid activation for binary classification
    Dense(2, activation='linear')
    ])
    
    # Compile the CNN model
    model.compile(
        optimizer='adam',  # Using the Adam optimizer for adaptive learning rate optimization
        loss='mse',  # Mean squared error loss function, suitable for regression tasks
        metrics=['mse']  # The model will report 'mse' as a performance metric
    )
    
    # Return the compiled model
    return model

# %% [markdown]
# ### 1.6 - Train 10 CNNs for F-region scaling and save the models

# %%
# This code trains 10 Convolutional Neural Networks (CNNs) on differently split subsets
# of a dataset for binary classification,saves the best model of each training session, 
# and records their training histories.

import os
import pickle
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Create the directory for saving models and histories if it doesn't exist
save_dir = 'F-scale'
os.makedirs(save_dir, exist_ok=True)

# Initialize lists to store the training histories and filenames of the best models
histories = []
model_filenames = []

# Define the ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,      # Factor to reduce the learning rate
    patience=10,     # Number of epochs with no improvement to wait before reducing LR
    min_lr=0.00001   # Minimum learning rate
)

# Loop to train 10 CNN models with different data splits
for i in range(10):
    # Split the dataset into training and validation sets
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=i)

    # Create a new CNN model for each iteration
    model = NOIREnet()

    # Define the filename for the checkpoint model
    model_filename = os.path.join(save_dir, f'F-scale_run{i+1}.h5')

    # Define a checkpoint callback to save the best model based on validation accuracy
    checkpoint_callback = ModelCheckpoint(
        model_filename,
        monitor='val_loss',
        verbose=1,
        save_best_only=True,
        mode='min',
        save_weights_only=False
    )

    # Train the model with specified callbacks including ReduceLROnPlateau
    history = model.fit(
        X_train, y_train,
        batch_size=64,
        epochs=100,
        validation_data=(X_val, y_val),
        callbacks=[checkpoint_callback, reduce_lr]  # Include ReduceLROnPlateau callback
    )

    # Save the training history and the filename of the saved best model
    histories.append(history.history)
    model_filenames.append(model_filename)

# Optionally, save the training histories to a file in the same 'F-scale' directory
history_filename = os.path.join(save_dir, 'training_histories.pkl')
with open(history_filename, 'wb') as file:
    pickle.dump({'histories': histories, 'model_filenames': model_filenames}, file)
# Out:
# Epoch 1/100
# 2023-11-29 12:09:15.247651: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 95/95 [==============================] - ETA: 0s - loss: 889.6645 - mse: 889.6645
# 2023-11-29 12:09:51.195625: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 3197.89429, saving model to E-scale/E-scale_run1.h5
# 95/95 [==============================] - 39s 388ms/step - loss: 889.6645 - mse: 889.6645 - val_loss: 3197.8943 - val_mse: 3197.8943 - lr: 0.0010
# Epoch 2/100
# 95/95 [==============================] - ETA: 0s - loss: 185.5725 - mse: 185.5725
# Epoch 2: val_loss did not improve from 3197.89429
# 95/95 [==============================] - 34s 352ms/step - loss: 185.5725 - mse: 185.5725 - val_loss: 4820.3823 - val_mse: 4820.3823 - lr: 0.0010
# Epoch 3/100
# 95/95 [==============================] - ETA: 0s - loss: 112.8841 - mse: 112.8841
# Epoch 3: val_loss did not improve from 3197.89429
# 95/95 [==============================] - 34s 359ms/step - loss: 112.8841 - mse: 112.8841 - val_loss: 3965.4512 - val_mse: 3965.4512 - lr: 0.0010
# Epoch 4/100
# 95/95 [==============================] - ETA: 0s - loss: 92.3370 - mse: 92.3370
# Epoch 4: val_loss did not improve from 3197.89429
# 95/95 [==============================] - 34s 358ms/step - loss: 92.3370 - mse: 92.3370 - val_loss: 31857.3887 - val_mse: 31857.3887 - lr: 0.0010
# Epoch 5/100
# 95/95 [==============================] - ETA: 0s - loss: 92.7355 - mse: 92.7355
# Epoch 5: val_loss improved from 3197.89429 to 711.55426, saving model to E-scale/E-scale_run1.h5
# 95/95 [==============================] - 34s 357ms/step - loss: 92.7355 - mse: 92.7355 - val_loss: 711.5543 - val_mse: 711.5543 - lr: 0.0010
# Epoch 6/100
# 95/95 [==============================] - ETA: 0s - loss: 75.8222 - mse: 75.8222
# Epoch 6: val_loss did not improve from 711.55426
# 95/95 [==============================] - 34s 352ms/step - loss: 75.8222 - mse: 75.8222 - val_loss: 889.7544 - val_mse: 889.7544 - lr: 0.0010
# Epoch 7/100
# 95/95 [==============================] - ETA: 0s - loss: 59.8384 - mse: 59.8384
# Epoch 7: val_loss improved from 711.55426 to 102.99246, saving model to E-scale/E-scale_run1.h5
# 95/95 [==============================] - 33s 350ms/step - loss: 59.8384 - mse: 59.8384 - val_loss: 102.9925 - val_mse: 102.9925 - lr: 0.0010
# Epoch 8/100
# 95/95 [==============================] - ETA: 0s - loss: 43.1544 - mse: 43.1544
# Epoch 8: val_loss did not improve from 102.99246
# 95/95 [==============================] - 33s 346ms/step - loss: 43.1544 - mse: 43.1544 - val_loss: 105.7495 - val_mse: 105.7495 - lr: 0.0010
# Epoch 9/100
# 95/95 [==============================] - ETA: 0s - loss: 36.9777 - mse: 36.9777
# Epoch 9: val_loss improved from 102.99246 to 83.62643, saving model to E-scale/E-scale_run1.h5
# 95/95 [==============================] - 34s 352ms/step - loss: 36.9777 - mse: 36.9777 - val_loss: 83.6264 - val_mse: 83.6264 - lr: 0.0010
# Epoch 10/100
# 95/95 [==============================] - ETA: 0s - loss: 49.4278 - mse: 49.4278
# Epoch 10: val_loss did not improve from 83.62643
# 95/95 [==============================] - 33s 348ms/step - loss: 49.4278 - mse: 49.4278 - val_loss: 105.2207 - val_mse: 105.2207 - lr: 0.0010
# Epoch 11/100
# 95/95 [==============================] - ETA: 0s - loss: 39.5431 - mse: 39.5431
# Epoch 11: val_loss improved from 83.62643 to 80.75742, saving model to E-scale/E-scale_run1.h5
# 95/95 [==============================] - 33s 347ms/step - loss: 39.5431 - mse: 39.5431 - val_loss: 80.7574 - val_mse: 80.7574 - lr: 0.0010
# Epoch 12/100
# 95/95 [==============================] - ETA: 0s - loss: 25.4154 - mse: 25.4154
# Epoch 12: val_loss did not improve from 80.75742
# 95/95 [==============================] - 33s 349ms/step - loss: 25.4154 - mse: 25.4154 - val_loss: 86.9834 - val_mse: 86.9834 - lr: 0.0010
# Epoch 13/100
# 95/95 [==============================] - ETA: 0s - loss: 25.5755 - mse: 25.5755
# Epoch 13: val_loss did not improve from 80.75742
# 95/95 [==============================] - 34s 355ms/step - loss: 25.5755 - mse: 25.5755 - val_loss: 1935.6360 - val_mse: 1935.6360 - lr: 0.0010
# Epoch 14/100
# 95/95 [==============================] - ETA: 0s - loss: 23.1334 - mse: 23.1334
# Epoch 14: val_loss improved from 80.75742 to 70.68211, saving model to E-scale/E-scale_run1.h5
# 95/95 [==============================] - 34s 356ms/step - loss: 23.1334 - mse: 23.1334 - val_loss: 70.6821 - val_mse: 70.6821 - lr: 0.0010
# Epoch 15/100
# 95/95 [==============================] - ETA: 0s - loss: 21.9587 - mse: 21.9587
# Epoch 15: val_loss did not improve from 70.68211
# 95/95 [==============================] - 34s 353ms/step - loss: 21.9587 - mse: 21.9587 - val_loss: 100.8823 - val_mse: 100.8823 - lr: 0.0010
# Epoch 16/100
# 95/95 [==============================] - ETA: 0s - loss: 21.8333 - mse: 21.8333
# Epoch 16: val_loss did not improve from 70.68211
# 95/95 [==============================] - 34s 353ms/step - loss: 21.8333 - mse: 21.8333 - val_loss: 71.5532 - val_mse: 71.5532 - lr: 0.0010
# Epoch 17/100
# 95/95 [==============================] - ETA: 0s - loss: 23.8169 - mse: 23.8169
# Epoch 17: val_loss did not improve from 70.68211
# 95/95 [==============================] - 34s 352ms/step - loss: 23.8169 - mse: 23.8169 - val_loss: 89.9264 - val_mse: 89.9264 - lr: 0.0010
# Epoch 18/100
# 95/95 [==============================] - ETA: 0s - loss: 23.6313 - mse: 23.6313
# Epoch 18: val_loss did not improve from 70.68211
# 95/95 [==============================] - 33s 347ms/step - loss: 23.6313 - mse: 23.6313 - val_loss: 92.2003 - val_mse: 92.2003 - lr: 0.0010
# Epoch 19/100
# 95/95 [==============================] - ETA: 0s - loss: 19.2274 - mse: 19.2274
# Epoch 19: val_loss did not improve from 70.68211
# 95/95 [==============================] - 34s 355ms/step - loss: 19.2274 - mse: 19.2274 - val_loss: 130.1852 - val_mse: 130.1852 - lr: 0.0010
# Epoch 20/100
# 95/95 [==============================] - ETA: 0s - loss: 19.4764 - mse: 19.4764
# Epoch 20: val_loss did not improve from 70.68211
# 95/95 [==============================] - 33s 349ms/step - loss: 19.4764 - mse: 19.4764 - val_loss: 137.7776 - val_mse: 137.7776 - lr: 0.0010
# Epoch 21/100
# 95/95 [==============================] - ETA: 0s - loss: 32.4316 - mse: 32.4316
# Epoch 21: val_loss did not improve from 70.68211
# 95/95 [==============================] - 34s 356ms/step - loss: 32.4316 - mse: 32.4316 - val_loss: 1934.3752 - val_mse: 1934.3752 - lr: 0.0010
# Epoch 22/100
# 95/95 [==============================] - ETA: 0s - loss: 68.9496 - mse: 68.9496
# Epoch 22: val_loss did not improve from 70.68211
# 95/95 [==============================] - 34s 357ms/step - loss: 68.9496 - mse: 68.9496 - val_loss: 368.5310 - val_mse: 368.5310 - lr: 0.0010
# Epoch 23/100
# 95/95 [==============================] - ETA: 0s - loss: 47.6993 - mse: 47.6993
# Epoch 23: val_loss did not improve from 70.68211
# 95/95 [==============================] - 34s 356ms/step - loss: 47.6993 - mse: 47.6993 - val_loss: 324.9892 - val_mse: 324.9892 - lr: 0.0010
# Epoch 24/100
# 95/95 [==============================] - ETA: 0s - loss: 36.9777 - mse: 36.9777
# Epoch 24: val_loss did not improve from 70.68211
# 95/95 [==============================] - 34s 352ms/step - loss: 36.9777 - mse: 36.9777 - val_loss: 94.1982 - val_mse: 94.1982 - lr: 0.0010
# Epoch 25/100
# 95/95 [==============================] - ETA: 0s - loss: 18.0530 - mse: 18.0530
# Epoch 25: val_loss improved from 70.68211 to 59.07973, saving model to E-scale/E-scale_run1.h5
# 95/95 [==============================] - 33s 348ms/step - loss: 18.0530 - mse: 18.0530 - val_loss: 59.0797 - val_mse: 59.0797 - lr: 1.0000e-04
# Epoch 26/100
# 95/95 [==============================] - ETA: 0s - loss: 13.5771 - mse: 13.5771
# Epoch 26: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 352ms/step - loss: 13.5771 - mse: 13.5771 - val_loss: 59.8515 - val_mse: 59.8515 - lr: 1.0000e-04
# Epoch 27/100
# 95/95 [==============================] - ETA: 0s - loss: 14.0447 - mse: 14.0447
# Epoch 27: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 356ms/step - loss: 14.0447 - mse: 14.0447 - val_loss: 67.4035 - val_mse: 67.4035 - lr: 1.0000e-04
# Epoch 28/100
# 95/95 [==============================] - ETA: 0s - loss: 11.5512 - mse: 11.5512
# Epoch 28: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 358ms/step - loss: 11.5512 - mse: 11.5512 - val_loss: 61.5911 - val_mse: 61.5911 - lr: 1.0000e-04
# Epoch 29/100
# 95/95 [==============================] - ETA: 0s - loss: 11.2339 - mse: 11.2339
# Epoch 29: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 356ms/step - loss: 11.2339 - mse: 11.2339 - val_loss: 65.3470 - val_mse: 65.3470 - lr: 1.0000e-04
# Epoch 30/100
# 95/95 [==============================] - ETA: 0s - loss: 9.2821 - mse: 9.2821
# Epoch 30: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 352ms/step - loss: 9.2821 - mse: 9.2821 - val_loss: 63.4398 - val_mse: 63.4398 - lr: 1.0000e-04
# Epoch 31/100
# 95/95 [==============================] - ETA: 0s - loss: 9.5909 - mse: 9.5909
# Epoch 31: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 352ms/step - loss: 9.5909 - mse: 9.5909 - val_loss: 62.1062 - val_mse: 62.1062 - lr: 1.0000e-04
# Epoch 32/100
# 95/95 [==============================] - ETA: 0s - loss: 8.4254 - mse: 8.4254
# Epoch 32: val_loss did not improve from 59.07973
# 95/95 [==============================] - 33s 349ms/step - loss: 8.4254 - mse: 8.4254 - val_loss: 63.7831 - val_mse: 63.7831 - lr: 1.0000e-04
# Epoch 33/100
# 95/95 [==============================] - ETA: 0s - loss: 7.7701 - mse: 7.7701
# Epoch 33: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 356ms/step - loss: 7.7701 - mse: 7.7701 - val_loss: 63.9442 - val_mse: 63.9442 - lr: 1.0000e-04
# Epoch 34/100
# 95/95 [==============================] - ETA: 0s - loss: 7.3070 - mse: 7.3070
# Epoch 34: val_loss did not improve from 59.07973
# 95/95 [==============================] - 33s 350ms/step - loss: 7.3070 - mse: 7.3070 - val_loss: 67.1452 - val_mse: 67.1452 - lr: 1.0000e-04
# Epoch 35/100
# 95/95 [==============================] - ETA: 0s - loss: 7.5841 - mse: 7.5841
# Epoch 35: val_loss did not improve from 59.07973
# 95/95 [==============================] - 33s 347ms/step - loss: 7.5841 - mse: 7.5841 - val_loss: 59.4540 - val_mse: 59.4540 - lr: 1.0000e-04
# Epoch 36/100
# 95/95 [==============================] - ETA: 0s - loss: 6.7884 - mse: 6.7884
# Epoch 36: val_loss did not improve from 59.07973
# 95/95 [==============================] - 33s 345ms/step - loss: 6.7884 - mse: 6.7884 - val_loss: 62.5371 - val_mse: 62.5371 - lr: 1.0000e-05
# Epoch 37/100
# 95/95 [==============================] - ETA: 0s - loss: 7.0717 - mse: 7.0717
# Epoch 37: val_loss did not improve from 59.07973
# 95/95 [==============================] - 33s 348ms/step - loss: 7.0717 - mse: 7.0717 - val_loss: 62.2289 - val_mse: 62.2289 - lr: 1.0000e-05
# Epoch 38/100
# 95/95 [==============================] - ETA: 0s - loss: 6.3712 - mse: 6.3712
# Epoch 38: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 352ms/step - loss: 6.3712 - mse: 6.3712 - val_loss: 61.4537 - val_mse: 61.4537 - lr: 1.0000e-05
# Epoch 39/100
# 95/95 [==============================] - ETA: 0s - loss: 6.3908 - mse: 6.3908
# Epoch 39: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 357ms/step - loss: 6.3908 - mse: 6.3908 - val_loss: 60.4631 - val_mse: 60.4631 - lr: 1.0000e-05
# Epoch 40/100
# 95/95 [==============================] - ETA: 0s - loss: 6.2517 - mse: 6.2517
# Epoch 40: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 355ms/step - loss: 6.2517 - mse: 6.2517 - val_loss: 60.8521 - val_mse: 60.8521 - lr: 1.0000e-05
# Epoch 41/100
# 95/95 [==============================] - ETA: 0s - loss: 6.2649 - mse: 6.2649
# Epoch 41: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 357ms/step - loss: 6.2649 - mse: 6.2649 - val_loss: 60.3912 - val_mse: 60.3912 - lr: 1.0000e-05
# Epoch 42/100
# 95/95 [==============================] - ETA: 0s - loss: 5.9595 - mse: 5.9595
# Epoch 42: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 355ms/step - loss: 5.9595 - mse: 5.9595 - val_loss: 60.6058 - val_mse: 60.6058 - lr: 1.0000e-05
# Epoch 43/100
# 95/95 [==============================] - ETA: 0s - loss: 6.1346 - mse: 6.1346
# Epoch 43: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 355ms/step - loss: 6.1346 - mse: 6.1346 - val_loss: 61.6340 - val_mse: 61.6340 - lr: 1.0000e-05
# Epoch 44/100
# 95/95 [==============================] - ETA: 0s - loss: 6.0718 - mse: 6.0718
# Epoch 44: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 355ms/step - loss: 6.0718 - mse: 6.0718 - val_loss: 60.5743 - val_mse: 60.5743 - lr: 1.0000e-05
# Epoch 45/100
# 95/95 [==============================] - ETA: 0s - loss: 6.3689 - mse: 6.3689
# Epoch 45: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 356ms/step - loss: 6.3689 - mse: 6.3689 - val_loss: 61.2039 - val_mse: 61.2039 - lr: 1.0000e-05
# Epoch 46/100
# 95/95 [==============================] - ETA: 0s - loss: 6.0092 - mse: 6.0092
# Epoch 46: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 352ms/step - loss: 6.0092 - mse: 6.0092 - val_loss: 60.3182 - val_mse: 60.3182 - lr: 1.0000e-05
# Epoch 47/100
# 95/95 [==============================] - ETA: 0s - loss: 6.1750 - mse: 6.1750
# Epoch 47: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 357ms/step - loss: 6.1750 - mse: 6.1750 - val_loss: 62.4386 - val_mse: 62.4386 - lr: 1.0000e-05
# Epoch 48/100
# 95/95 [==============================] - ETA: 0s - loss: 5.9602 - mse: 5.9602
# Epoch 48: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 356ms/step - loss: 5.9602 - mse: 5.9602 - val_loss: 60.3210 - val_mse: 60.3210 - lr: 1.0000e-05
# Epoch 49/100
# 95/95 [==============================] - ETA: 0s - loss: 6.0717 - mse: 6.0717
# Epoch 49: val_loss did not improve from 59.07973
# 95/95 [==============================] - 33s 351ms/step - loss: 6.0717 - mse: 6.0717 - val_loss: 61.1391 - val_mse: 61.1391 - lr: 1.0000e-05
# Epoch 50/100
# 95/95 [==============================] - ETA: 0s - loss: 6.1853 - mse: 6.1853
# Epoch 50: val_loss did not improve from 59.07973
# 95/95 [==============================] - 33s 347ms/step - loss: 6.1853 - mse: 6.1853 - val_loss: 59.3432 - val_mse: 59.3432 - lr: 1.0000e-05
# Epoch 51/100
# 95/95 [==============================] - ETA: 0s - loss: 5.9617 - mse: 5.9617
# Epoch 51: val_loss did not improve from 59.07973
# 95/95 [==============================] - 33s 345ms/step - loss: 5.9617 - mse: 5.9617 - val_loss: 62.9616 - val_mse: 62.9616 - lr: 1.0000e-05
# Epoch 52/100
# 95/95 [==============================] - ETA: 0s - loss: 6.0966 - mse: 6.0966
# Epoch 52: val_loss did not improve from 59.07973
# 95/95 [==============================] - 33s 349ms/step - loss: 6.0966 - mse: 6.0966 - val_loss: 61.5932 - val_mse: 61.5932 - lr: 1.0000e-05
# Epoch 53/100
# 95/95 [==============================] - ETA: 0s - loss: 5.6126 - mse: 5.6126
# Epoch 53: val_loss did not improve from 59.07973
# 95/95 [==============================] - 33s 347ms/step - loss: 5.6126 - mse: 5.6126 - val_loss: 61.5573 - val_mse: 61.5573 - lr: 1.0000e-05
# Epoch 54/100
# 95/95 [==============================] - ETA: 0s - loss: 5.5924 - mse: 5.5924
# Epoch 54: val_loss did not improve from 59.07973
# 95/95 [==============================] - 33s 347ms/step - loss: 5.5924 - mse: 5.5924 - val_loss: 62.8258 - val_mse: 62.8258 - lr: 1.0000e-05
# Epoch 55/100
# 95/95 [==============================] - ETA: 0s - loss: 5.7336 - mse: 5.7336
# Epoch 55: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 355ms/step - loss: 5.7336 - mse: 5.7336 - val_loss: 60.6179 - val_mse: 60.6179 - lr: 1.0000e-05
# Epoch 56/100
# 95/95 [==============================] - ETA: 0s - loss: 5.5817 - mse: 5.5817
# Epoch 56: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 359ms/step - loss: 5.5817 - mse: 5.5817 - val_loss: 61.1382 - val_mse: 61.1382 - lr: 1.0000e-05
# Epoch 57/100
# 95/95 [==============================] - ETA: 0s - loss: 5.5068 - mse: 5.5068
# Epoch 57: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 357ms/step - loss: 5.5068 - mse: 5.5068 - val_loss: 61.4289 - val_mse: 61.4289 - lr: 1.0000e-05
# Epoch 58/100
# 95/95 [==============================] - ETA: 0s - loss: 5.4698 - mse: 5.4698
# Epoch 58: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 353ms/step - loss: 5.4698 - mse: 5.4698 - val_loss: 60.6928 - val_mse: 60.6928 - lr: 1.0000e-05
# Epoch 59/100
# 95/95 [==============================] - ETA: 0s - loss: 5.2239 - mse: 5.2239
# Epoch 59: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 354ms/step - loss: 5.2239 - mse: 5.2239 - val_loss: 63.3452 - val_mse: 63.3452 - lr: 1.0000e-05
# Epoch 60/100
# 95/95 [==============================] - ETA: 0s - loss: 5.4998 - mse: 5.4998
# Epoch 60: val_loss did not improve from 59.07973
# 95/95 [==============================] - 33s 349ms/step - loss: 5.4998 - mse: 5.4998 - val_loss: 61.8707 - val_mse: 61.8707 - lr: 1.0000e-05
# Epoch 61/100
# 95/95 [==============================] - ETA: 0s - loss: 5.5324 - mse: 5.5324
# Epoch 61: val_loss did not improve from 59.07973
# 95/95 [==============================] - 33s 346ms/step - loss: 5.5324 - mse: 5.5324 - val_loss: 63.1786 - val_mse: 63.1786 - lr: 1.0000e-05
# Epoch 62/100
# 95/95 [==============================] - ETA: 0s - loss: 5.3905 - mse: 5.3905
# Epoch 62: val_loss did not improve from 59.07973
# 95/95 [==============================] - 33s 341ms/step - loss: 5.3905 - mse: 5.3905 - val_loss: 62.5252 - val_mse: 62.5252 - lr: 1.0000e-05
# Epoch 63/100
# 95/95 [==============================] - ETA: 0s - loss: 5.2663 - mse: 5.2663
# Epoch 63: val_loss did not improve from 59.07973
# 95/95 [==============================] - 33s 349ms/step - loss: 5.2663 - mse: 5.2663 - val_loss: 62.3538 - val_mse: 62.3538 - lr: 1.0000e-05
# Epoch 64/100
# 95/95 [==============================] - ETA: 0s - loss: 5.4347 - mse: 5.4347
# Epoch 64: val_loss did not improve from 59.07973
# 95/95 [==============================] - 34s 352ms/step - loss: 5.4347 - mse: 5.4347 - val_loss: 61.5157 - val_mse: 61.5157 - lr: 1.0000e-05
# Epoch 65/100
# 95/95 [==============================] - ETA: 0s - loss: 5.1905 - mse: 5.1905
# Epoch 65: val_loss improved from 59.07973 to 59.06363, saving model to E-scale/E-scale_run1.h5
# 95/95 [==============================] - 34s 351ms/step - loss: 5.1905 - mse: 5.1905 - val_loss: 59.0636 - val_mse: 59.0636 - lr: 1.0000e-05
# Epoch 66/100
# 95/95 [==============================] - ETA: 0s - loss: 4.9511 - mse: 4.9511
# Epoch 66: val_loss did not improve from 59.06363
# 95/95 [==============================] - 34s 353ms/step - loss: 4.9511 - mse: 4.9511 - val_loss: 60.5725 - val_mse: 60.5725 - lr: 1.0000e-05
# Epoch 67/100
# 95/95 [==============================] - ETA: 0s - loss: 4.7048 - mse: 4.7048
# Epoch 67: val_loss did not improve from 59.06363
# 95/95 [==============================] - 34s 353ms/step - loss: 4.7048 - mse: 4.7048 - val_loss: 60.9424 - val_mse: 60.9424 - lr: 1.0000e-05
# Epoch 68/100
# 95/95 [==============================] - ETA: 0s - loss: 4.9887 - mse: 4.9887
# Epoch 68: val_loss did not improve from 59.06363
# 95/95 [==============================] - 34s 354ms/step - loss: 4.9887 - mse: 4.9887 - val_loss: 61.0107 - val_mse: 61.0107 - lr: 1.0000e-05
# Epoch 69/100
# 95/95 [==============================] - ETA: 0s - loss: 5.0607 - mse: 5.0607
# Epoch 69: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 350ms/step - loss: 5.0607 - mse: 5.0607 - val_loss: 61.0277 - val_mse: 61.0277 - lr: 1.0000e-05
# Epoch 70/100
# 95/95 [==============================] - ETA: 0s - loss: 4.8528 - mse: 4.8528
# Epoch 70: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 350ms/step - loss: 4.8528 - mse: 4.8528 - val_loss: 60.7734 - val_mse: 60.7734 - lr: 1.0000e-05
# Epoch 71/100
# 95/95 [==============================] - ETA: 0s - loss: 5.0071 - mse: 5.0071
# Epoch 71: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 344ms/step - loss: 5.0071 - mse: 5.0071 - val_loss: 61.4273 - val_mse: 61.4273 - lr: 1.0000e-05
# Epoch 72/100
# 95/95 [==============================] - ETA: 0s - loss: 4.5458 - mse: 4.5458
# Epoch 72: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 344ms/step - loss: 4.5458 - mse: 4.5458 - val_loss: 61.0598 - val_mse: 61.0598 - lr: 1.0000e-05
# Epoch 73/100
# 95/95 [==============================] - ETA: 0s - loss: 4.5926 - mse: 4.5926
# Epoch 73: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 343ms/step - loss: 4.5926 - mse: 4.5926 - val_loss: 61.3709 - val_mse: 61.3709 - lr: 1.0000e-05
# Epoch 74/100
# 95/95 [==============================] - ETA: 0s - loss: 4.7320 - mse: 4.7320
# Epoch 74: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 345ms/step - loss: 4.7320 - mse: 4.7320 - val_loss: 61.9292 - val_mse: 61.9292 - lr: 1.0000e-05
# Epoch 75/100
# 95/95 [==============================] - ETA: 0s - loss: 4.7191 - mse: 4.7191
# Epoch 75: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 348ms/step - loss: 4.7191 - mse: 4.7191 - val_loss: 61.5936 - val_mse: 61.5936 - lr: 1.0000e-05
# Epoch 76/100
# 95/95 [==============================] - ETA: 0s - loss: 4.6117 - mse: 4.6117
# Epoch 76: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 349ms/step - loss: 4.6117 - mse: 4.6117 - val_loss: 62.9076 - val_mse: 62.9076 - lr: 1.0000e-05
# Epoch 77/100
# 95/95 [==============================] - ETA: 0s - loss: 4.4029 - mse: 4.4029
# Epoch 77: val_loss did not improve from 59.06363
# 95/95 [==============================] - 34s 354ms/step - loss: 4.4029 - mse: 4.4029 - val_loss: 60.0400 - val_mse: 60.0400 - lr: 1.0000e-05
# Epoch 78/100
# 95/95 [==============================] - ETA: 0s - loss: 4.4872 - mse: 4.4872
# Epoch 78: val_loss did not improve from 59.06363
# 95/95 [==============================] - 34s 353ms/step - loss: 4.4872 - mse: 4.4872 - val_loss: 61.5324 - val_mse: 61.5324 - lr: 1.0000e-05
# Epoch 79/100
# 95/95 [==============================] - ETA: 0s - loss: 4.4652 - mse: 4.4652
# Epoch 79: val_loss did not improve from 59.06363
# 95/95 [==============================] - 34s 356ms/step - loss: 4.4652 - mse: 4.4652 - val_loss: 62.0524 - val_mse: 62.0524 - lr: 1.0000e-05
# Epoch 80/100
# 95/95 [==============================] - ETA: 0s - loss: 4.2693 - mse: 4.2693
# Epoch 80: val_loss did not improve from 59.06363
# 95/95 [==============================] - 34s 354ms/step - loss: 4.2693 - mse: 4.2693 - val_loss: 60.8021 - val_mse: 60.8021 - lr: 1.0000e-05
# Epoch 81/100
# 95/95 [==============================] - ETA: 0s - loss: 4.3701 - mse: 4.3701
# Epoch 81: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 347ms/step - loss: 4.3701 - mse: 4.3701 - val_loss: 63.2309 - val_mse: 63.2309 - lr: 1.0000e-05
# Epoch 82/100
# 95/95 [==============================] - ETA: 0s - loss: 4.0724 - mse: 4.0724
# Epoch 82: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 345ms/step - loss: 4.0724 - mse: 4.0724 - val_loss: 64.1621 - val_mse: 64.1621 - lr: 1.0000e-05
# Epoch 83/100
# 95/95 [==============================] - ETA: 0s - loss: 4.2194 - mse: 4.2194
# Epoch 83: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 343ms/step - loss: 4.2194 - mse: 4.2194 - val_loss: 62.2065 - val_mse: 62.2065 - lr: 1.0000e-05
# Epoch 84/100
# 95/95 [==============================] - ETA: 0s - loss: 4.0757 - mse: 4.0757
# Epoch 84: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 350ms/step - loss: 4.0757 - mse: 4.0757 - val_loss: 60.3531 - val_mse: 60.3531 - lr: 1.0000e-05
# Epoch 85/100
# 95/95 [==============================] - ETA: 0s - loss: 4.3848 - mse: 4.3848
# Epoch 85: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 349ms/step - loss: 4.3848 - mse: 4.3848 - val_loss: 62.5129 - val_mse: 62.5129 - lr: 1.0000e-05
# Epoch 86/100
# 95/95 [==============================] - ETA: 0s - loss: 4.0977 - mse: 4.0977
# Epoch 86: val_loss did not improve from 59.06363
# 95/95 [==============================] - 34s 358ms/step - loss: 4.0977 - mse: 4.0977 - val_loss: 61.1105 - val_mse: 61.1105 - lr: 1.0000e-05
# Epoch 87/100
# 95/95 [==============================] - ETA: 0s - loss: 4.1772 - mse: 4.1772
# Epoch 87: val_loss did not improve from 59.06363
# 95/95 [==============================] - 34s 358ms/step - loss: 4.1772 - mse: 4.1772 - val_loss: 60.8413 - val_mse: 60.8413 - lr: 1.0000e-05
# Epoch 88/100
# 95/95 [==============================] - ETA: 0s - loss: 4.2375 - mse: 4.2375
# Epoch 88: val_loss did not improve from 59.06363
# 95/95 [==============================] - 34s 357ms/step - loss: 4.2375 - mse: 4.2375 - val_loss: 60.0102 - val_mse: 60.0102 - lr: 1.0000e-05
# Epoch 89/100
# 95/95 [==============================] - ETA: 0s - loss: 4.1583 - mse: 4.1583
# Epoch 89: val_loss did not improve from 59.06363
# 95/95 [==============================] - 34s 359ms/step - loss: 4.1583 - mse: 4.1583 - val_loss: 61.0995 - val_mse: 61.0995 - lr: 1.0000e-05
# Epoch 90/100
# 95/95 [==============================] - ETA: 0s - loss: 3.8614 - mse: 3.8614
# Epoch 90: val_loss did not improve from 59.06363
# 95/95 [==============================] - 35s 367ms/step - loss: 3.8614 - mse: 3.8614 - val_loss: 61.1684 - val_mse: 61.1684 - lr: 1.0000e-05
# Epoch 91/100
# 95/95 [==============================] - ETA: 0s - loss: 3.8441 - mse: 3.8441
# Epoch 91: val_loss did not improve from 59.06363
# 95/95 [==============================] - 34s 357ms/step - loss: 3.8441 - mse: 3.8441 - val_loss: 60.2701 - val_mse: 60.2701 - lr: 1.0000e-05
# Epoch 92/100
# 95/95 [==============================] - ETA: 0s - loss: 3.7053 - mse: 3.7053
# Epoch 92: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 351ms/step - loss: 3.7053 - mse: 3.7053 - val_loss: 59.7718 - val_mse: 59.7718 - lr: 1.0000e-05
# Epoch 93/100
# 95/95 [==============================] - ETA: 0s - loss: 3.9785 - mse: 3.9785
# Epoch 93: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 351ms/step - loss: 3.9785 - mse: 3.9785 - val_loss: 61.8120 - val_mse: 61.8120 - lr: 1.0000e-05
# Epoch 94/100
# 95/95 [==============================] - ETA: 0s - loss: 3.6025 - mse: 3.6025
# Epoch 94: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 350ms/step - loss: 3.6025 - mse: 3.6025 - val_loss: 61.6099 - val_mse: 61.6099 - lr: 1.0000e-05
# Epoch 95/100
# 95/95 [==============================] - ETA: 0s - loss: 3.6428 - mse: 3.6428
# Epoch 95: val_loss did not improve from 59.06363
# 95/95 [==============================] - 34s 355ms/step - loss: 3.6428 - mse: 3.6428 - val_loss: 60.8145 - val_mse: 60.8145 - lr: 1.0000e-05
# Epoch 96/100
# 95/95 [==============================] - ETA: 0s - loss: 3.7243 - mse: 3.7243
# Epoch 96: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 348ms/step - loss: 3.7243 - mse: 3.7243 - val_loss: 62.2326 - val_mse: 62.2326 - lr: 1.0000e-05
# Epoch 97/100
# 95/95 [==============================] - ETA: 0s - loss: 3.8169 - mse: 3.8169
# Epoch 97: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 342ms/step - loss: 3.8169 - mse: 3.8169 - val_loss: 60.1422 - val_mse: 60.1422 - lr: 1.0000e-05
# Epoch 98/100
# 95/95 [==============================] - ETA: 0s - loss: 3.5881 - mse: 3.5881
# Epoch 98: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 341ms/step - loss: 3.5881 - mse: 3.5881 - val_loss: 61.6048 - val_mse: 61.6048 - lr: 1.0000e-05
# Epoch 99/100
# 95/95 [==============================] - ETA: 0s - loss: 3.5096 - mse: 3.5096
# Epoch 99: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 342ms/step - loss: 3.5096 - mse: 3.5096 - val_loss: 60.3549 - val_mse: 60.3549 - lr: 1.0000e-05
# Epoch 100/100
# 95/95 [==============================] - ETA: 0s - loss: 3.6057 - mse: 3.6057
# Epoch 100: val_loss did not improve from 59.06363
# 95/95 [==============================] - 33s 350ms/step - loss: 3.6057 - mse: 3.6057 - val_loss: 61.6852 - val_mse: 61.6852 - lr: 1.0000e-05
# Epoch 1/100
# 2023-11-29 13:05:17.582791: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 95/95 [==============================] - ETA: 0s - loss: 962.0424 - mse: 962.0424
# 2023-11-29 13:05:50.892393: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 3288.43408, saving model to E-scale/E-scale_run2.h5
# 95/95 [==============================] - 37s 360ms/step - loss: 962.0424 - mse: 962.0424 - val_loss: 3288.4341 - val_mse: 3288.4341 - lr: 0.0010
# Epoch 2/100
# 95/95 [==============================] - ETA: 0s - loss: 156.0898 - mse: 156.0898
# Epoch 2: val_loss improved from 3288.43408 to 1975.59192, saving model to E-scale/E-scale_run2.h5
# 95/95 [==============================] - 34s 352ms/step - loss: 156.0898 - mse: 156.0898 - val_loss: 1975.5919 - val_mse: 1975.5919 - lr: 0.0010
# Epoch 3/100
# 95/95 [==============================] - ETA: 0s - loss: 117.1943 - mse: 117.1943
# Epoch 3: val_loss improved from 1975.59192 to 1899.05969, saving model to E-scale/E-scale_run2.h5
# 95/95 [==============================] - 34s 354ms/step - loss: 117.1943 - mse: 117.1943 - val_loss: 1899.0597 - val_mse: 1899.0597 - lr: 0.0010
# Epoch 4/100
# 95/95 [==============================] - ETA: 0s - loss: 124.6047 - mse: 124.6047
# Epoch 4: val_loss did not improve from 1899.05969
# 95/95 [==============================] - 34s 353ms/step - loss: 124.6047 - mse: 124.6047 - val_loss: 2870.7244 - val_mse: 2870.7244 - lr: 0.0010
# Epoch 5/100
# 95/95 [==============================] - ETA: 0s - loss: 78.3401 - mse: 78.3401
# Epoch 5: val_loss did not improve from 1899.05969
# 95/95 [==============================] - 33s 348ms/step - loss: 78.3401 - mse: 78.3401 - val_loss: 3382.2644 - val_mse: 3382.2644 - lr: 0.0010
# Epoch 6/100
# 95/95 [==============================] - ETA: 0s - loss: 61.0909 - mse: 61.0909
# Epoch 6: val_loss improved from 1899.05969 to 1391.39807, saving model to E-scale/E-scale_run2.h5
# 95/95 [==============================] - 33s 346ms/step - loss: 61.0909 - mse: 61.0909 - val_loss: 1391.3981 - val_mse: 1391.3981 - lr: 0.0010
# Epoch 7/100
# 95/95 [==============================] - ETA: 0s - loss: 59.2514 - mse: 59.2514
# Epoch 7: val_loss improved from 1391.39807 to 238.90041, saving model to E-scale/E-scale_run2.h5
# 95/95 [==============================] - 33s 346ms/step - loss: 59.2514 - mse: 59.2514 - val_loss: 238.9004 - val_mse: 238.9004 - lr: 0.0010
# Epoch 8/100
# 95/95 [==============================] - ETA: 0s - loss: 49.1586 - mse: 49.1586
# Epoch 8: val_loss improved from 238.90041 to 98.60955, saving model to E-scale/E-scale_run2.h5
# 95/95 [==============================] - 34s 356ms/step - loss: 49.1586 - mse: 49.1586 - val_loss: 98.6096 - val_mse: 98.6096 - lr: 0.0010
# Epoch 9/100
# 95/95 [==============================] - ETA: 0s - loss: 40.0082 - mse: 40.0082
# Epoch 9: val_loss improved from 98.60955 to 82.56036, saving model to E-scale/E-scale_run2.h5
# 95/95 [==============================] - 34s 354ms/step - loss: 40.0082 - mse: 40.0082 - val_loss: 82.5604 - val_mse: 82.5604 - lr: 0.0010
# Epoch 10/100
# 95/95 [==============================] - ETA: 0s - loss: 36.5256 - mse: 36.5256
# Epoch 10: val_loss did not improve from 82.56036
# 95/95 [==============================] - 34s 354ms/step - loss: 36.5256 - mse: 36.5256 - val_loss: 103.1682 - val_mse: 103.1682 - lr: 0.0010
# Epoch 11/100
# 95/95 [==============================] - ETA: 0s - loss: 38.1686 - mse: 38.1686
# Epoch 11: val_loss did not improve from 82.56036
# 95/95 [==============================] - 34s 355ms/step - loss: 38.1686 - mse: 38.1686 - val_loss: 97.5549 - val_mse: 97.5549 - lr: 0.0010
# Epoch 12/100
# 95/95 [==============================] - ETA: 0s - loss: 41.8065 - mse: 41.8065
# Epoch 12: val_loss did not improve from 82.56036
# 95/95 [==============================] - 34s 355ms/step - loss: 41.8065 - mse: 41.8065 - val_loss: 91.8144 - val_mse: 91.8144 - lr: 0.0010
# Epoch 13/100
# 95/95 [==============================] - ETA: 0s - loss: 32.2627 - mse: 32.2627
# Epoch 13: val_loss improved from 82.56036 to 77.89063, saving model to E-scale/E-scale_run2.h5
# 95/95 [==============================] - 34s 357ms/step - loss: 32.2627 - mse: 32.2627 - val_loss: 77.8906 - val_mse: 77.8906 - lr: 0.0010
# Epoch 14/100
# 95/95 [==============================] - ETA: 0s - loss: 27.9316 - mse: 27.9316
# Epoch 14: val_loss did not improve from 77.89063
# 95/95 [==============================] - 34s 353ms/step - loss: 27.9316 - mse: 27.9316 - val_loss: 94.8988 - val_mse: 94.8988 - lr: 0.0010
# Epoch 15/100
# 95/95 [==============================] - ETA: 0s - loss: 21.1924 - mse: 21.1924
# Epoch 15: val_loss improved from 77.89063 to 76.24495, saving model to E-scale/E-scale_run2.h5
# 95/95 [==============================] - 34s 356ms/step - loss: 21.1924 - mse: 21.1924 - val_loss: 76.2449 - val_mse: 76.2449 - lr: 0.0010
# Epoch 16/100
# 95/95 [==============================] - ETA: 0s - loss: 16.2055 - mse: 16.2055
# Epoch 16: val_loss improved from 76.24495 to 75.66657, saving model to E-scale/E-scale_run2.h5
# 95/95 [==============================] - 34s 352ms/step - loss: 16.2055 - mse: 16.2055 - val_loss: 75.6666 - val_mse: 75.6666 - lr: 0.0010
# Epoch 17/100
# 95/95 [==============================] - ETA: 0s - loss: 20.0608 - mse: 20.0608
# Epoch 17: val_loss did not improve from 75.66657
# 95/95 [==============================] - 33s 348ms/step - loss: 20.0608 - mse: 20.0608 - val_loss: 105.0332 - val_mse: 105.0332 - lr: 0.0010
# Epoch 18/100
# 95/95 [==============================] - ETA: 0s - loss: 19.3878 - mse: 19.3878
# Epoch 18: val_loss did not improve from 75.66657
# 95/95 [==============================] - 34s 353ms/step - loss: 19.3878 - mse: 19.3878 - val_loss: 102.1721 - val_mse: 102.1721 - lr: 0.0010
# Epoch 19/100
# 95/95 [==============================] - ETA: 0s - loss: 14.3779 - mse: 14.3779
# Epoch 19: val_loss did not improve from 75.66657
# 95/95 [==============================] - 33s 346ms/step - loss: 14.3779 - mse: 14.3779 - val_loss: 108.0349 - val_mse: 108.0349 - lr: 0.0010
# Epoch 20/100
# 95/95 [==============================] - ETA: 0s - loss: 15.6110 - mse: 15.6110
# Epoch 20: val_loss improved from 75.66657 to 71.67058, saving model to E-scale/E-scale_run2.h5
# 95/95 [==============================] - 34s 353ms/step - loss: 15.6110 - mse: 15.6110 - val_loss: 71.6706 - val_mse: 71.6706 - lr: 0.0010
# Epoch 21/100
# 95/95 [==============================] - ETA: 0s - loss: 18.1768 - mse: 18.1768
# Epoch 21: val_loss did not improve from 71.67058
# 95/95 [==============================] - 33s 346ms/step - loss: 18.1768 - mse: 18.1768 - val_loss: 80.4141 - val_mse: 80.4141 - lr: 0.0010
# Epoch 22/100
# 95/95 [==============================] - ETA: 0s - loss: 15.9005 - mse: 15.9005
# Epoch 22: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 354ms/step - loss: 15.9005 - mse: 15.9005 - val_loss: 75.5701 - val_mse: 75.5701 - lr: 0.0010
# Epoch 23/100
# 95/95 [==============================] - ETA: 0s - loss: 14.7153 - mse: 14.7153
# Epoch 23: val_loss did not improve from 71.67058
# 95/95 [==============================] - 33s 344ms/step - loss: 14.7153 - mse: 14.7153 - val_loss: 77.0270 - val_mse: 77.0270 - lr: 0.0010
# Epoch 24/100
# 95/95 [==============================] - ETA: 0s - loss: 17.4693 - mse: 17.4693
# Epoch 24: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 357ms/step - loss: 17.4693 - mse: 17.4693 - val_loss: 86.0348 - val_mse: 86.0348 - lr: 0.0010
# Epoch 25/100
# 95/95 [==============================] - ETA: 0s - loss: 25.5161 - mse: 25.5161
# Epoch 25: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 354ms/step - loss: 25.5161 - mse: 25.5161 - val_loss: 215.9305 - val_mse: 215.9305 - lr: 0.0010
# Epoch 26/100
# 95/95 [==============================] - ETA: 0s - loss: 29.9652 - mse: 29.9652
# Epoch 26: val_loss did not improve from 71.67058
# 95/95 [==============================] - 33s 344ms/step - loss: 29.9652 - mse: 29.9652 - val_loss: 182.2073 - val_mse: 182.2073 - lr: 0.0010
# Epoch 27/100
# 95/95 [==============================] - ETA: 0s - loss: 27.7275 - mse: 27.7275
# Epoch 27: val_loss did not improve from 71.67058
# 95/95 [==============================] - 33s 343ms/step - loss: 27.7275 - mse: 27.7275 - val_loss: 1185.3870 - val_mse: 1185.3870 - lr: 0.0010
# Epoch 28/100
# 95/95 [==============================] - ETA: 0s - loss: 45.4099 - mse: 45.4099
# Epoch 28: val_loss did not improve from 71.67058
# 95/95 [==============================] - 33s 348ms/step - loss: 45.4099 - mse: 45.4099 - val_loss: 59305.7578 - val_mse: 59305.7578 - lr: 0.0010
# Epoch 29/100
# 95/95 [==============================] - ETA: 0s - loss: 41.3551 - mse: 41.3551
# Epoch 29: val_loss did not improve from 71.67058
# 95/95 [==============================] - 33s 347ms/step - loss: 41.3551 - mse: 41.3551 - val_loss: 195.0338 - val_mse: 195.0338 - lr: 0.0010
# Epoch 30/100
# 95/95 [==============================] - ETA: 0s - loss: 25.6315 - mse: 25.6315
# Epoch 30: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 355ms/step - loss: 25.6315 - mse: 25.6315 - val_loss: 88.8147 - val_mse: 88.8147 - lr: 0.0010
# Epoch 31/100
# 95/95 [==============================] - ETA: 0s - loss: 15.4134 - mse: 15.4134
# Epoch 31: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 356ms/step - loss: 15.4134 - mse: 15.4134 - val_loss: 91.4784 - val_mse: 91.4784 - lr: 1.0000e-04
# Epoch 32/100
# 95/95 [==============================] - ETA: 0s - loss: 11.8235 - mse: 11.8235
# Epoch 32: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 356ms/step - loss: 11.8235 - mse: 11.8235 - val_loss: 94.6453 - val_mse: 94.6453 - lr: 1.0000e-04
# Epoch 33/100
# 95/95 [==============================] - ETA: 0s - loss: 10.6965 - mse: 10.6965
# Epoch 33: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 352ms/step - loss: 10.6965 - mse: 10.6965 - val_loss: 90.4478 - val_mse: 90.4478 - lr: 1.0000e-04
# Epoch 34/100
# 95/95 [==============================] - ETA: 0s - loss: 8.9142 - mse: 8.9142
# Epoch 34: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 355ms/step - loss: 8.9142 - mse: 8.9142 - val_loss: 89.6519 - val_mse: 89.6519 - lr: 1.0000e-04
# Epoch 35/100
# 95/95 [==============================] - ETA: 0s - loss: 8.2811 - mse: 8.2811
# Epoch 35: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 354ms/step - loss: 8.2811 - mse: 8.2811 - val_loss: 88.3573 - val_mse: 88.3573 - lr: 1.0000e-04
# Epoch 36/100
# 95/95 [==============================] - ETA: 0s - loss: 7.7083 - mse: 7.7083
# Epoch 36: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 356ms/step - loss: 7.7083 - mse: 7.7083 - val_loss: 90.3629 - val_mse: 90.3629 - lr: 1.0000e-04
# Epoch 37/100
# 95/95 [==============================] - ETA: 0s - loss: 7.5422 - mse: 7.5422
# Epoch 37: val_loss did not improve from 71.67058
# 95/95 [==============================] - 33s 347ms/step - loss: 7.5422 - mse: 7.5422 - val_loss: 88.2883 - val_mse: 88.2883 - lr: 1.0000e-04
# Epoch 38/100
# 95/95 [==============================] - ETA: 0s - loss: 6.9279 - mse: 6.9279
# Epoch 38: val_loss did not improve from 71.67058
# 95/95 [==============================] - 33s 346ms/step - loss: 6.9279 - mse: 6.9279 - val_loss: 94.2509 - val_mse: 94.2509 - lr: 1.0000e-04
# Epoch 39/100
# 95/95 [==============================] - ETA: 0s - loss: 6.3658 - mse: 6.3658
# Epoch 39: val_loss did not improve from 71.67058
# 95/95 [==============================] - 33s 348ms/step - loss: 6.3658 - mse: 6.3658 - val_loss: 90.8479 - val_mse: 90.8479 - lr: 1.0000e-04
# Epoch 40/100
# 95/95 [==============================] - ETA: 0s - loss: 6.2151 - mse: 6.2151
# Epoch 40: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 356ms/step - loss: 6.2151 - mse: 6.2151 - val_loss: 92.1353 - val_mse: 92.1353 - lr: 1.0000e-04
# Epoch 41/100
# 95/95 [==============================] - ETA: 0s - loss: 5.6688 - mse: 5.6688
# Epoch 41: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 355ms/step - loss: 5.6688 - mse: 5.6688 - val_loss: 89.1588 - val_mse: 89.1588 - lr: 1.0000e-05
# Epoch 42/100
# 95/95 [==============================] - ETA: 0s - loss: 5.5109 - mse: 5.5109
# Epoch 42: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 354ms/step - loss: 5.5109 - mse: 5.5109 - val_loss: 89.4433 - val_mse: 89.4433 - lr: 1.0000e-05
# Epoch 43/100
# 95/95 [==============================] - ETA: 0s - loss: 5.4226 - mse: 5.4226
# Epoch 43: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 354ms/step - loss: 5.4226 - mse: 5.4226 - val_loss: 88.9954 - val_mse: 88.9954 - lr: 1.0000e-05
# Epoch 44/100
# 95/95 [==============================] - ETA: 0s - loss: 5.4385 - mse: 5.4385
# Epoch 44: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 355ms/step - loss: 5.4385 - mse: 5.4385 - val_loss: 90.1750 - val_mse: 90.1750 - lr: 1.0000e-05
# Epoch 45/100
# 95/95 [==============================] - ETA: 0s - loss: 5.4039 - mse: 5.4039
# Epoch 45: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 354ms/step - loss: 5.4039 - mse: 5.4039 - val_loss: 89.9767 - val_mse: 89.9767 - lr: 1.0000e-05
# Epoch 46/100
# 95/95 [==============================] - ETA: 0s - loss: 5.4293 - mse: 5.4293
# Epoch 46: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 356ms/step - loss: 5.4293 - mse: 5.4293 - val_loss: 88.1352 - val_mse: 88.1352 - lr: 1.0000e-05
# Epoch 47/100
# 95/95 [==============================] - ETA: 0s - loss: 5.1863 - mse: 5.1863
# Epoch 47: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 355ms/step - loss: 5.1863 - mse: 5.1863 - val_loss: 90.1581 - val_mse: 90.1581 - lr: 1.0000e-05
# Epoch 48/100
# 95/95 [==============================] - ETA: 0s - loss: 5.3245 - mse: 5.3245
# Epoch 48: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 355ms/step - loss: 5.3245 - mse: 5.3245 - val_loss: 89.2337 - val_mse: 89.2337 - lr: 1.0000e-05
# Epoch 49/100
# 95/95 [==============================] - ETA: 0s - loss: 5.2294 - mse: 5.2294
# Epoch 49: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 355ms/step - loss: 5.2294 - mse: 5.2294 - val_loss: 89.9389 - val_mse: 89.9389 - lr: 1.0000e-05
# Epoch 50/100
# 95/95 [==============================] - ETA: 0s - loss: 5.1822 - mse: 5.1822
# Epoch 50: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 357ms/step - loss: 5.1822 - mse: 5.1822 - val_loss: 89.8116 - val_mse: 89.8116 - lr: 1.0000e-05
# Epoch 51/100
# 95/95 [==============================] - ETA: 0s - loss: 5.2839 - mse: 5.2839
# Epoch 51: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 354ms/step - loss: 5.2839 - mse: 5.2839 - val_loss: 87.8027 - val_mse: 87.8027 - lr: 1.0000e-05
# Epoch 52/100
# 95/95 [==============================] - ETA: 0s - loss: 5.1020 - mse: 5.1020
# Epoch 52: val_loss did not improve from 71.67058
# 95/95 [==============================] - 33s 346ms/step - loss: 5.1020 - mse: 5.1020 - val_loss: 90.1026 - val_mse: 90.1026 - lr: 1.0000e-05
# Epoch 53/100
# 95/95 [==============================] - ETA: 0s - loss: 5.1169 - mse: 5.1169
# Epoch 53: val_loss did not improve from 71.67058
# 95/95 [==============================] - 33s 346ms/step - loss: 5.1169 - mse: 5.1169 - val_loss: 90.4739 - val_mse: 90.4739 - lr: 1.0000e-05
# Epoch 54/100
# 95/95 [==============================] - ETA: 0s - loss: 5.3022 - mse: 5.3022
# Epoch 54: val_loss did not improve from 71.67058
# 95/95 [==============================] - 33s 345ms/step - loss: 5.3022 - mse: 5.3022 - val_loss: 89.5269 - val_mse: 89.5269 - lr: 1.0000e-05
# Epoch 55/100
# 95/95 [==============================] - ETA: 0s - loss: 5.0740 - mse: 5.0740
# Epoch 55: val_loss did not improve from 71.67058
# 95/95 [==============================] - 33s 347ms/step - loss: 5.0740 - mse: 5.0740 - val_loss: 87.0981 - val_mse: 87.0981 - lr: 1.0000e-05
# Epoch 56/100
# 95/95 [==============================] - ETA: 0s - loss: 4.9792 - mse: 4.9792
# Epoch 56: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 354ms/step - loss: 4.9792 - mse: 4.9792 - val_loss: 90.4093 - val_mse: 90.4093 - lr: 1.0000e-05
# Epoch 57/100
# 95/95 [==============================] - ETA: 0s - loss: 5.1081 - mse: 5.1081
# Epoch 57: val_loss did not improve from 71.67058
# 95/95 [==============================] - 33s 347ms/step - loss: 5.1081 - mse: 5.1081 - val_loss: 91.1778 - val_mse: 91.1778 - lr: 1.0000e-05
# Epoch 58/100
# 95/95 [==============================] - ETA: 0s - loss: 4.9776 - mse: 4.9776
# Epoch 58: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 356ms/step - loss: 4.9776 - mse: 4.9776 - val_loss: 88.7607 - val_mse: 88.7607 - lr: 1.0000e-05
# Epoch 59/100
# 95/95 [==============================] - ETA: 0s - loss: 4.8353 - mse: 4.8353
# Epoch 59: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 354ms/step - loss: 4.8353 - mse: 4.8353 - val_loss: 88.2641 - val_mse: 88.2641 - lr: 1.0000e-05
# Epoch 60/100
# 95/95 [==============================] - ETA: 0s - loss: 4.8803 - mse: 4.8803
# Epoch 60: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 358ms/step - loss: 4.8803 - mse: 4.8803 - val_loss: 86.9771 - val_mse: 86.9771 - lr: 1.0000e-05
# Epoch 61/100
# 95/95 [==============================] - ETA: 0s - loss: 4.6972 - mse: 4.6972
# Epoch 61: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 357ms/step - loss: 4.6972 - mse: 4.6972 - val_loss: 88.5951 - val_mse: 88.5951 - lr: 1.0000e-05
# Epoch 62/100
# 95/95 [==============================] - ETA: 0s - loss: 4.7080 - mse: 4.7080
# Epoch 62: val_loss did not improve from 71.67058
# 95/95 [==============================] - 34s 357ms/step - loss: 4.7080 - mse: 4.7080 - val_loss: 88.1836 - val_mse: 88.1836 - lr: 1.0000e-05
# Epoch 63/100
# 95/95 [==============================] - ETA: 0s - loss: 4.8041 - mse: 4.8041
# Epoch 63: val_loss did not improve from 71.67058
# 95/95 [==============================] - 33s 347ms/step - loss: 4.8041 - mse: 4.8041 - val_loss: 89.2139 - val_mse: 89.2139 - lr: 1.0000e-05
# Epoch 64/100
# 95/95 [==============================] - ETA: 0s - loss: 4.6525 - mse: 4.6525
# Epoch 64: val_loss did not improve from 71.67058
# 95/95 [==============================] - 33s 345ms/step - loss: 4.6525 - mse: 4.6525 - val_loss: 89.1939 - val_mse: 89.1939 - lr: 1.0000e-05
# Epoch 65/100
# 95/95 [==============================] - ETA: 0s - loss: 4.6941 - mse: 4.6941
# Epoch 65: val_loss did not improve from 71.67058
# ...
# Epoch 6/100
# 95/95 [==============================] - ETA: 0s - loss: 54.5127 - mse: 54.5127
# Epoch 6: val_loss improved from 1419.41052 to 719.38696, saving model to E-scale/E-scale_run10.h5
# 95/95 [==============================] - 33s 351ms/step - loss: 54.5127 - mse: 54.5127 - val_loss: 719.3870 - val_mse: 719.3870 - lr: 0.0010
# Epoch 7/100
# 95/95 [==============================] - ETA: 0s - loss: 60.1235 - mse: 60.1235
# Epoch 7: val_loss did not improve from 719.38696
# 95/95 [==============================] - 33s 347ms/step - loss: 60.1235 - mse: 60.1235 - val_loss: 1096.7583 - val_mse: 1096.7583 - lr: 0.0010
# Epoch 8/100
# 95/95 [==============================] - ETA: 0s - loss: 77.4355 - mse: 77.4355
# Epoch 8: val_loss improved from 719.38696 to 162.52338, saving model to E-scale/E-scale_run10.h5
# 95/95 [==============================] - 33s 350ms/step - loss: 77.4355 - mse: 77.4355 - val_loss: 162.5234 - val_mse: 162.5234 - lr: 0.0010
# Epoch 9/100
# 95/95 [==============================] - ETA: 0s - loss: 60.7749 - mse: 60.7749
# Epoch 9: val_loss improved from 162.52338 to 96.23868, saving model to E-scale/E-scale_run10.h5
# 95/95 [==============================] - 33s 349ms/step - loss: 60.7749 - mse: 60.7749 - val_loss: 96.2387 - val_mse: 96.2387 - lr: 0.0010
# Epoch 10/100
# 95/95 [==============================] - ETA: 0s - loss: 42.9951 - mse: 42.9951
# Epoch 10: val_loss did not improve from 96.23868
# 95/95 [==============================] - 33s 348ms/step - loss: 42.9951 - mse: 42.9951 - val_loss: 129.1991 - val_mse: 129.1991 - lr: 0.0010
# Epoch 11/100
# 95/95 [==============================] - ETA: 0s - loss: 34.8191 - mse: 34.8191
# Epoch 11: val_loss improved from 96.23868 to 87.87975, saving model to E-scale/E-scale_run10.h5
# 95/95 [==============================] - 32s 338ms/step - loss: 34.8191 - mse: 34.8191 - val_loss: 87.8797 - val_mse: 87.8797 - lr: 0.0010
# Epoch 12/100
# 95/95 [==============================] - ETA: 0s - loss: 32.0986 - mse: 32.0986
# Epoch 12: val_loss improved from 87.87975 to 77.71988, saving model to E-scale/E-scale_run10.h5
# 95/95 [==============================] - 32s 337ms/step - loss: 32.0986 - mse: 32.0986 - val_loss: 77.7199 - val_mse: 77.7199 - lr: 0.0010
# Epoch 13/100
# 95/95 [==============================] - ETA: 0s - loss: 27.1957 - mse: 27.1957
# Epoch 13: val_loss did not improve from 77.71988
# 95/95 [==============================] - 32s 334ms/step - loss: 27.1957 - mse: 27.1957 - val_loss: 87.4891 - val_mse: 87.4891 - lr: 0.0010
# Epoch 14/100
# 95/95 [==============================] - ETA: 0s - loss: 31.0756 - mse: 31.0756
# Epoch 14: val_loss did not improve from 77.71988
# 95/95 [==============================] - 32s 338ms/step - loss: 31.0756 - mse: 31.0756 - val_loss: 95.6680 - val_mse: 95.6680 - lr: 0.0010
# Epoch 15/100
# 95/95 [==============================] - ETA: 0s - loss: 22.2137 - mse: 22.2137
# Epoch 15: val_loss did not improve from 77.71988
# 95/95 [==============================] - 33s 348ms/step - loss: 22.2137 - mse: 22.2137 - val_loss: 78.2902 - val_mse: 78.2902 - lr: 0.0010
# Epoch 16/100
# 95/95 [==============================] - ETA: 0s - loss: 21.9575 - mse: 21.9575
# Epoch 16: val_loss did not improve from 77.71988
# 95/95 [==============================] - 33s 348ms/step - loss: 21.9575 - mse: 21.9575 - val_loss: 149.6357 - val_mse: 149.6357 - lr: 0.0010
# Epoch 17/100
# 95/95 [==============================] - ETA: 0s - loss: 25.0584 - mse: 25.0584
# Epoch 17: val_loss did not improve from 77.71988
# 95/95 [==============================] - 33s 349ms/step - loss: 25.0584 - mse: 25.0584 - val_loss: 146.0777 - val_mse: 146.0777 - lr: 0.0010
# Epoch 18/100
# 95/95 [==============================] - ETA: 0s - loss: 45.0177 - mse: 45.0177
# Epoch 18: val_loss did not improve from 77.71988
# 95/95 [==============================] - 33s 348ms/step - loss: 45.0177 - mse: 45.0177 - val_loss: 2080.0071 - val_mse: 2080.0071 - lr: 0.0010
# Epoch 19/100
# 95/95 [==============================] - ETA: 0s - loss: 35.4206 - mse: 35.4206
# Epoch 19: val_loss did not improve from 77.71988
# 95/95 [==============================] - 33s 351ms/step - loss: 35.4206 - mse: 35.4206 - val_loss: 92.4893 - val_mse: 92.4893 - lr: 0.0010
# Epoch 20/100
# 95/95 [==============================] - ETA: 0s - loss: 29.8636 - mse: 29.8636
# Epoch 20: val_loss did not improve from 77.71988
# 95/95 [==============================] - 33s 350ms/step - loss: 29.8636 - mse: 29.8636 - val_loss: 78.0576 - val_mse: 78.0576 - lr: 0.0010
# Epoch 21/100
# 95/95 [==============================] - ETA: 0s - loss: 19.0416 - mse: 19.0416
# Epoch 21: val_loss improved from 77.71988 to 73.05533, saving model to E-scale/E-scale_run10.h5
# 95/95 [==============================] - 34s 352ms/step - loss: 19.0416 - mse: 19.0416 - val_loss: 73.0553 - val_mse: 73.0553 - lr: 0.0010
# Epoch 22/100
# 95/95 [==============================] - ETA: 0s - loss: 17.1459 - mse: 17.1459
# Epoch 22: val_loss did not improve from 73.05533
# 95/95 [==============================] - 34s 352ms/step - loss: 17.1459 - mse: 17.1459 - val_loss: 77.4940 - val_mse: 77.4940 - lr: 0.0010
# Epoch 23/100
# 95/95 [==============================] - ETA: 0s - loss: 15.2033 - mse: 15.2033
# Epoch 23: val_loss improved from 73.05533 to 72.51188, saving model to E-scale/E-scale_run10.h5
# 95/95 [==============================] - 33s 348ms/step - loss: 15.2033 - mse: 15.2033 - val_loss: 72.5119 - val_mse: 72.5119 - lr: 0.0010
# Epoch 24/100
# 95/95 [==============================] - ETA: 0s - loss: 13.4263 - mse: 13.4263
# Epoch 24: val_loss did not improve from 72.51188
# 95/95 [==============================] - 32s 337ms/step - loss: 13.4263 - mse: 13.4263 - val_loss: 72.9187 - val_mse: 72.9187 - lr: 0.0010
# Epoch 25/100
# 95/95 [==============================] - ETA: 0s - loss: 14.8506 - mse: 14.8506
# Epoch 25: val_loss did not improve from 72.51188
# 95/95 [==============================] - 33s 344ms/step - loss: 14.8506 - mse: 14.8506 - val_loss: 92.4359 - val_mse: 92.4359 - lr: 0.0010
# Epoch 26/100
# 95/95 [==============================] - ETA: 0s - loss: 15.7618 - mse: 15.7618
# Epoch 26: val_loss did not improve from 72.51188
# 95/95 [==============================] - 33s 345ms/step - loss: 15.7618 - mse: 15.7618 - val_loss: 80.6180 - val_mse: 80.6180 - lr: 0.0010
# Epoch 27/100
# 95/95 [==============================] - ETA: 0s - loss: 18.1951 - mse: 18.1951
# Epoch 27: val_loss did not improve from 72.51188
# 95/95 [==============================] - 33s 344ms/step - loss: 18.1951 - mse: 18.1951 - val_loss: 79.7581 - val_mse: 79.7581 - lr: 0.0010
# Epoch 28/100
# 95/95 [==============================] - ETA: 0s - loss: 19.3998 - mse: 19.3998
# Epoch 28: val_loss did not improve from 72.51188
# 95/95 [==============================] - 33s 344ms/step - loss: 19.3998 - mse: 19.3998 - val_loss: 120.3878 - val_mse: 120.3878 - lr: 0.0010
# Epoch 29/100
# 95/95 [==============================] - ETA: 0s - loss: 22.4512 - mse: 22.4512
# Epoch 29: val_loss did not improve from 72.51188
# 95/95 [==============================] - 32s 337ms/step - loss: 22.4512 - mse: 22.4512 - val_loss: 88.2413 - val_mse: 88.2413 - lr: 0.0010
# Epoch 30/100
# 95/95 [==============================] - ETA: 0s - loss: 17.8432 - mse: 17.8432
# Epoch 30: val_loss did not improve from 72.51188
# 95/95 [==============================] - 32s 335ms/step - loss: 17.8432 - mse: 17.8432 - val_loss: 87.4227 - val_mse: 87.4227 - lr: 0.0010
# Epoch 31/100
# 95/95 [==============================] - ETA: 0s - loss: 18.4016 - mse: 18.4016
# Epoch 31: val_loss did not improve from 72.51188
# 95/95 [==============================] - 33s 343ms/step - loss: 18.4016 - mse: 18.4016 - val_loss: 207.3083 - val_mse: 207.3083 - lr: 0.0010
# Epoch 32/100
# 95/95 [==============================] - ETA: 0s - loss: 19.2882 - mse: 19.2882
# Epoch 32: val_loss did not improve from 72.51188
# 95/95 [==============================] - 33s 345ms/step - loss: 19.2882 - mse: 19.2882 - val_loss: 83.2040 - val_mse: 83.2040 - lr: 0.0010
# Epoch 33/100
# 95/95 [==============================] - ETA: 0s - loss: 20.6656 - mse: 20.6656
# Epoch 33: val_loss did not improve from 72.51188
# 95/95 [==============================] - 33s 344ms/step - loss: 20.6656 - mse: 20.6656 - val_loss: 107.5720 - val_mse: 107.5720 - lr: 0.0010
# Epoch 34/100
# 95/95 [==============================] - ETA: 0s - loss: 13.5517 - mse: 13.5517
# Epoch 34: val_loss improved from 72.51188 to 72.00558, saving model to E-scale/E-scale_run10.h5
# 95/95 [==============================] - 33s 346ms/step - loss: 13.5517 - mse: 13.5517 - val_loss: 72.0056 - val_mse: 72.0056 - lr: 1.0000e-04
# Epoch 35/100
# 95/95 [==============================] - ETA: 0s - loss: 8.6383 - mse: 8.6383
# Epoch 35: val_loss did not improve from 72.00558
# 95/95 [==============================] - 33s 344ms/step - loss: 8.6383 - mse: 8.6383 - val_loss: 74.7037 - val_mse: 74.7037 - lr: 1.0000e-04
# Epoch 36/100
# 95/95 [==============================] - ETA: 0s - loss: 7.1184 - mse: 7.1184
# Epoch 36: val_loss did not improve from 72.00558
# 95/95 [==============================] - 33s 345ms/step - loss: 7.1184 - mse: 7.1184 - val_loss: 75.3177 - val_mse: 75.3177 - lr: 1.0000e-04
# Epoch 37/100
# 95/95 [==============================] - ETA: 0s - loss: 6.1348 - mse: 6.1348
# Epoch 37: val_loss did not improve from 72.00558
# 95/95 [==============================] - 33s 344ms/step - loss: 6.1348 - mse: 6.1348 - val_loss: 78.2129 - val_mse: 78.2129 - lr: 1.0000e-04
# Epoch 38/100
# 95/95 [==============================] - ETA: 0s - loss: 5.6166 - mse: 5.6166
# Epoch 38: val_loss did not improve from 72.00558
# 95/95 [==============================] - 33s 344ms/step - loss: 5.6166 - mse: 5.6166 - val_loss: 74.5932 - val_mse: 74.5932 - lr: 1.0000e-04
# Epoch 39/100
# 95/95 [==============================] - ETA: 0s - loss: 4.9081 - mse: 4.9081
# Epoch 39: val_loss did not improve from 72.00558
# 95/95 [==============================] - 33s 343ms/step - loss: 4.9081 - mse: 4.9081 - val_loss: 74.3963 - val_mse: 74.3963 - lr: 1.0000e-04
# Epoch 40/100
# 95/95 [==============================] - ETA: 0s - loss: 4.8938 - mse: 4.8938
# Epoch 40: val_loss did not improve from 72.00558
# 95/95 [==============================] - 32s 335ms/step - loss: 4.8938 - mse: 4.8938 - val_loss: 80.8683 - val_mse: 80.8683 - lr: 1.0000e-04
# Epoch 41/100
# 95/95 [==============================] - ETA: 0s - loss: 4.8658 - mse: 4.8658
# Epoch 41: val_loss did not improve from 72.00558
# 95/95 [==============================] - 32s 335ms/step - loss: 4.8658 - mse: 4.8658 - val_loss: 82.1856 - val_mse: 82.1856 - lr: 1.0000e-04
# Epoch 42/100
# 95/95 [==============================] - ETA: 0s - loss: 4.3286 - mse: 4.3286
# Epoch 42: val_loss did not improve from 72.00558
# 95/95 [==============================] - 32s 336ms/step - loss: 4.3286 - mse: 4.3286 - val_loss: 78.5468 - val_mse: 78.5468 - lr: 1.0000e-04
# Epoch 43/100
# 95/95 [==============================] - ETA: 0s - loss: 4.4651 - mse: 4.4651
# Epoch 43: val_loss did not improve from 72.00558
# 95/95 [==============================] - 33s 342ms/step - loss: 4.4651 - mse: 4.4651 - val_loss: 77.3537 - val_mse: 77.3537 - lr: 1.0000e-04
# Epoch 44/100
# 95/95 [==============================] - ETA: 0s - loss: 4.4980 - mse: 4.4980
# Epoch 44: val_loss did not improve from 72.00558
# 95/95 [==============================] - 33s 345ms/step - loss: 4.4980 - mse: 4.4980 - val_loss: 80.6828 - val_mse: 80.6828 - lr: 1.0000e-04
# Epoch 45/100
# 95/95 [==============================] - ETA: 0s - loss: 3.7664 - mse: 3.7664
# Epoch 45: val_loss did not improve from 72.00558
# 95/95 [==============================] - 33s 344ms/step - loss: 3.7664 - mse: 3.7664 - val_loss: 78.4510 - val_mse: 78.4510 - lr: 1.0000e-05
# Epoch 46/100
# 95/95 [==============================] - ETA: 0s - loss: 3.8624 - mse: 3.8624
# Epoch 46: val_loss did not improve from 72.00558
# 95/95 [==============================] - 33s 344ms/step - loss: 3.8624 - mse: 3.8624 - val_loss: 77.4233 - val_mse: 77.4233 - lr: 1.0000e-05
# Epoch 47/100
# 95/95 [==============================] - ETA: 0s - loss: 3.5897 - mse: 3.5897
# Epoch 47: val_loss did not improve from 72.00558
# 95/95 [==============================] - 33s 345ms/step - loss: 3.5897 - mse: 3.5897 - val_loss: 77.3284 - val_mse: 77.3284 - lr: 1.0000e-05
# Epoch 48/100
# 95/95 [==============================] - ETA: 0s - loss: 3.5455 - mse: 3.5455
# Epoch 48: val_loss did not improve from 72.00558
# 95/95 [==============================] - 33s 342ms/step - loss: 3.5455 - mse: 3.5455 - val_loss: 77.7887 - val_mse: 77.7887 - lr: 1.0000e-05
# Epoch 49/100
# 95/95 [==============================] - ETA: 0s - loss: 3.4196 - mse: 3.4196
# Epoch 49: val_loss did not improve from 72.00558
# 95/95 [==============================] - 32s 336ms/step - loss: 3.4196 - mse: 3.4196 - val_loss: 77.4936 - val_mse: 77.4936 - lr: 1.0000e-05
# Epoch 50/100
# 95/95 [==============================] - ETA: 0s - loss: 3.5710 - mse: 3.5710
# Epoch 50: val_loss did not improve from 72.00558
# 95/95 [==============================] - 33s 341ms/step - loss: 3.5710 - mse: 3.5710 - val_loss: 77.9857 - val_mse: 77.9857 - lr: 1.0000e-05
# Epoch 51/100
# 95/95 [==============================] - ETA: 0s - loss: 3.3643 - mse: 3.3643
# Epoch 51: val_loss did not improve from 72.00558
# 95/95 [==============================] - 32s 339ms/step - loss: 3.3643 - mse: 3.3643 - val_loss: 77.5660 - val_mse: 77.5660 - lr: 1.0000e-05
# Epoch 52/100
# 95/95 [==============================] - ETA: 0s - loss: 3.2370 - mse: 3.2370
# Epoch 52: val_loss did not improve from 72.00558
# 95/95 [==============================] - 32s 340ms/step - loss: 3.2370 - mse: 3.2370 - val_loss: 77.6431 - val_mse: 77.6431 - lr: 1.0000e-05
# Epoch 53/100
# 95/95 [==============================] - ETA: 0s - loss: 3.4664 - mse: 3.4664
# Epoch 53: val_loss did not improve from 72.00558
# 95/95 [==============================] - 32s 339ms/step - loss: 3.4664 - mse: 3.4664 - val_loss: 77.1302 - val_mse: 77.1302 - lr: 1.0000e-05
# Epoch 54/100
# 95/95 [==============================] - ETA: 0s - loss: 3.6187 - mse: 3.6187
# Epoch 54: val_loss did not improve from 72.00558
# 95/95 [==============================] - 32s 340ms/step - loss: 3.6187 - mse: 3.6187 - val_loss: 77.4145 - val_mse: 77.4145 - lr: 1.0000e-05
# Epoch 55/100
# 95/95 [==============================] - ETA: 0s - loss: 3.1755 - mse: 3.1755
# Epoch 55: val_loss did not improve from 72.00558
# 95/95 [==============================] - 33s 347ms/step - loss: 3.1755 - mse: 3.1755 - val_loss: 78.1340 - val_mse: 78.1340 - lr: 1.0000e-05
# Epoch 56/100
# 95/95 [==============================] - ETA: 0s - loss: 3.3088 - mse: 3.3088
# Epoch 56: val_loss did not improve from 72.00558
# 95/95 [==============================] - 33s 341ms/step - loss: 3.3088 - mse: 3.3088 - val_loss: 78.1210 - val_mse: 78.1210 - lr: 1.0000e-05
# Epoch 57/100
# 95/95 [==============================] - ETA: 0s - loss: 3.8596 - mse: 3.8596
# Epoch 57: val_loss did not improve from 72.00558
# 95/95 [==============================] - 34s 352ms/step - loss: 3.8596 - mse: 3.8596 - val_loss: 77.0657 - val_mse: 77.0657 - lr: 1.0000e-05
# Epoch 58/100
# 95/95 [==============================] - ETA: 0s - loss: 3.3260 - mse: 3.3260
# Epoch 58: val_loss did not improve from 72.00558
# 95/95 [==============================] - 33s 341ms/step - loss: 3.3260 - mse: 3.3260 - val_loss: 77.7762 - val_mse: 77.7762 - lr: 1.0000e-05
# Epoch 59/100
# 95/95 [==============================] - ETA: 0s - loss: 3.6606 - mse: 3.6606
# Epoch 59: val_loss did not improve from 72.00558
# 95/95 [==============================] - 33s 349ms/step - loss: 3.6606 - mse: 3.6606 - val_loss: 77.4179 - val_mse: 77.4179 - lr: 1.0000e-05
# Epoch 60/100
# 95/95 [==============================] - ETA: 0s - loss: 3.3891 - mse: 3.3891
# Epoch 60: val_loss did not improve from 72.00558
# 95/95 [==============================] - 33s 343ms/step - loss: 3.3891 - mse: 3.3891 - val_loss: 77.4587 - val_mse: 77.4587 - lr: 1.0000e-05
# Epoch 61/100
# 67/95 [====================>.........] - ETA: 9s - loss: 3.2152 - mse: 3.2152

# %% [markdown]
# ## 2 - Test the performance of NOIRE-Net on an independent test set

# %% [markdown]
# ### 2.1 - Define a function to get ionogram labels from the testing data

# %%
# This code defines the get_majority_label function which determines the majority label 
# (True or False) among a list of .par files, and in case of a tie, it randomly selects a label.
def get_majority_label(par_files):
    # Extract labels from each .par file using the get_regression_label_from_par function
    labels = [get_regression_label_from_par(f) for f in par_files]

    # If the majority of labels are True, return True
    if labels.count(True) > len(labels) / 2:
        return True
    # If the majority of labels are False, return False
    elif labels.count(False) > len(labels) / 2:
        return False
    # If there is a tie between True and False labels, randomly choose one
    else:
        return random.choice([True, False])  # Randomize in case of a tie

# %% [markdown]
# ### 2.2 - Define a function to load and process test images

# %%
# This code defines the load_and_preprocess_image function, which loads an image from a 
# specified path, converts it to grayscale, resizes it to 310x310 pixels, normalizes its pixel
# values, and returns the processed image as an array.
def load_and_preprocess_image(image_path):
    # Load the image from the given path, convert it to grayscale, and resize it to 310x310 pixels
    image = load_img(image_path, color_mode='grayscale', target_size=(310, 310))

    # Convert the image to a numpy array
    image = img_to_array(image)

    # Normalize the pixel values to be in the range [0, 1]
    image /= 255.0

    # Return the preprocessed image
    return image

# %% [markdown]
# ### 2.3 - Load the trained models with the highest validation accuracy

# %%
# Define function to load models
def load_models(models_dir):
    return [load_model(os.path.join(models_dir, mf)) for mf in os.listdir(models_dir) if mf.endswith('.h5')]

# Specify the directory where the trained models are stored
models_dir = 'E-classify'

# Load the models
models = load_models(models_dir)

# %% [markdown]
# ### 2.4 - Define a function to prepare the resting data for comparison with CNNs

# %%
# This function prepares the testing dataset by loading and processing images from a 
# specified directory and determining corresponding human labels based on majority voting
# from associated .par files.
def prepare_test_data(ionograms_dir, parameters_dir):
    X_test = []  # List to store preprocessed images
    y_human = []  # List to store corresponding human labels

    # Cache the paths of all .par files for efficient access
    par_files_cache = {f: os.path.join(parameters_dir, f) for f in os.listdir(parameters_dir)}

    # Iterate through each image file in the ionograms directory
    for img_file in os.listdir(ionograms_dir):
        if img_file.endswith('.png'):  # Only process .png files
            img_path = os.path.join(ionograms_dir, img_file)
            X_test.append(load_and_preprocess_image(img_path))  # Load and preprocess the image

            # Extract timestamp from the image filename
            timestamp = os.path.splitext(img_file)[0]

            # Get all .par files relevant to the current image based on timestamp
            relevant_par_files = [fpath for fname, fpath in par_files_cache.items() if timestamp in fname]
            y_human.append(get_majority_label(relevant_par_files))  # Determine the majority label

    # Convert lists to numpy arrays
    return np.array(X_test), np.array(y_human).astype(int)

# %% [markdown]
# ### 2.5 - Define a function compare the CNN predictions to the human labeling

# %%
# This function evaluates a list of pre-loaded CNN models on a prepared test dataset, calculates key
# performance metrics (precision, recall, F1-score, accuracy), prints their mean and standard deviation,
# and returns the normalized confusion matrices for each model.
def evaluate_models(models, X_test, y_human):
    metrics = {'precision': [], 'recall': [], 'f1': [], 'accuracy': []}  # Dictionary to store metrics for each model
    confusion_matrices = []  # List to store confusion matrices for each model

    # Iterate over each model and evaluate it
    for model in models:
        y_pred = model.predict(X_test).round().astype(int)  # Predict labels for the test dataset

        # Calculate and store the performance metrics for the current model
        metrics['precision'].append(precision_score(y_human, y_pred))
        metrics['recall'].append(recall_score(y_human, y_pred))
        metrics['f1'].append(f1_score(y_human, y_pred))
        metrics['accuracy'].append(accuracy_score(y_human, y_pred))

        # Calculate and store the normalized confusion matrix
        confusion_matrices.append(confusion_matrix(y_human, y_pred, normalize='true'))

    # Print the mean and standard deviation for each metric
    for metric, values in metrics.items():
        print(f"Mean {metric.capitalize()}: {np.mean(values):.3f}, Std {metric.capitalize()}: {np.std(values):.3f}")

    return confusion_matrices

# %% [markdown]
# ### 2.6 - Specify testing directories and prepare testing data

# %%
# Specify the directory where the testing data is located
testing_dir = 'testing'

# Specify the directory where the input ionograms are located
ionograms_dir = os.path.join(testing_dir, 'ionograms')

# Specify the directory where the output parameters are located
parameters_dir = os.path.join(testing_dir, 'parameters')

# Load and prepare the testing data
X_test, y_human = prepare_test_data(ionograms_dir, parameters_dir)

# %% [markdown]
# ### 2.7 - Evaluate the models using precision, recall, F1-score, accuracy

# %%
# Evaluate the models located in 'models_dir' using the test data in 'testing_dir'
# and store the returned confusion matrices
confusion_matrices = evaluate_models(models, X_test, y_human)

# %% [markdown]
# ### 2.8 - Calculate the mean and standard deviation of TP, FN, FP and TN

# %%
# Convert list of confusion matrices to a 3D NumPy array for easier calculations
confusion_matrices = np.array(confusion_matrices)

# Calculate mean and standard deviation for TP, FN, FP, TN
mean_tp = np.mean(confusion_matrices[:, 1, 1])
std_tp = np.std(confusion_matrices[:, 1, 1])

mean_fn = np.mean(confusion_matrices[:, 1, 0])
std_fn = np.std(confusion_matrices[:, 1, 0])

mean_fp = np.mean(confusion_matrices[:, 0, 1])
std_fp = np.std(confusion_matrices[:, 0, 1])

mean_tn = np.mean(confusion_matrices[:, 0, 0])
std_tn = np.std(confusion_matrices[:, 0, 0])

# Metrics, means, and standard deviations
means = [mean_tp, mean_fn, mean_fp, mean_tn]
std_devs = [std_tp, std_fn, std_fp, std_tn]

# %% [markdown]
# ## 3 - Display the confusion matrix

# %% [markdown]
# ### 3.1 - Define Function for Text Color Based on Background

# %%
# This function determines the text color (black or white) based on the background color's
# luminance for better readability.
def text_color_based_on_bg(bg_color):
    # Calculate the perceptual luminance of the color
    luminance = (0.299 * bg_color[0] + 0.587 * bg_color[1] + 0.114 * bg_color[2])
    return 'white' if luminance < 0.5 else 'black'

# %% [markdown]
# ### 3.2 - Plot the Confusion Matrix Statistics

# %%
# This code creates a 2x2 plot with colored squares representing the mean and standard 
# deviation of TP, FN, FP, and TN from the confusion matrices.

# Setup color map with normalization between 0 and 1
cmap = plt.cm.inferno
norm = mcolors.Normalize(vmin=0, vmax=1)

# Create a 2x2 subplot figure with adjusted spacing
fig, axs = plt.subplots(2, 2, figsize=(6, 6))
axs = axs.flatten()

means = [mean_tp, mean_fn, mean_fp, mean_tn]
std_devs = [std_tp, std_fn, std_fp, std_tn]

# Iterate over each subplot to add the confusion matrix data
for i, ax in enumerate(axs):
    color = cmap(norm(means[i]))  # Set the color based on the mean value
    ax.add_patch(plt.Rectangle((0, 0), 1, 1, color=color))  # Create a colored square

    text_color = text_color_based_on_bg(color)  # Determine text color
    text = f'{means[i]:.3f} ± {std_devs[i]:.3f}'  # Format text for mean ± std deviation
    ax.text(0.5, 0.5, text, ha='center', va='center', fontsize=14, color=text_color)  # Add text to the subplot

    ax.axis('off')  # Remove axes

# Adjust subplot parameters so squares touch each other
plt.subplots_adjust(wspace=0, hspace=0)

# Add a colorbar and adjust its font size
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm, ax=axs, orientation='horizontal', fraction=0.046, pad=0.04)
cbar.ax.tick_params(labelsize=14)  # Set font size for colorbar ticks

plt.show()
